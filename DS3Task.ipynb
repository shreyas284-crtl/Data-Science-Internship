# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas284-crtl/Data-Science-Internship/blob/main/DS3Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number_to_reverse = 256

# Convert the number to a string
num_str = str(number_to_reverse)

# Reverse the string
reversed_str = num_str[::-1]

# Convert the reversed string back to an integer
reversed_number = int(reversed_str)

print(f"The original number is: {number_to_reverse}")
print(f"The reversed number is: {reversed_number}")
# Out:
# The original number is: 256
# The reversed number is: 652

# %%
n = int(input())
unique = [int(x) for x in set(str(n))]
print(unique)
# Out:
# 5685
# [6, 5, 8]

# %%
from collections import Counter

s = "Shreyasbs"
d = Counter(s)

res = [c for c, cnt in d.items() if cnt > 1]
print(res)
# Out:
# ['s']

# %%
number = 3456
num_str = str(number)
digit_count = len(num_str)

print(f"The number of digits in {number} is: {digit_count}")
# Out:
# The number of digits in 3456 is: 4

# %%
# Given string
x = "Hello World"

# Reverse string using slicing
x_reversed = x[::-1]

print(f"Original string : {x}")
print(f"Reversed string : {x_reversed}")
# Out:
# Original string : Hello World
# Reversed string : dlroW olleH

# %%
def cigar_party(cigars, is_weekend):
	if is_weekend:
		return cigars >= 40
	return 40 <= cigars <= 60

print(
cigar_party(30, False),
cigar_party(50, False),
cigar_party(70, True))
# Out:
# False True True
