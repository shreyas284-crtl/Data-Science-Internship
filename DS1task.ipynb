# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas284-crtl/Data-Science-Internship/blob/main/DS1task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My name is Shreyas")
# Out:
# My name is Shreyas

# %%
print("2")
# Out:
# 2

# %%
print("2+2")
# Out:
# 2+2

# %%
print(2+2)
# Out:
# 4

# %%
print(2-2)
print(2*2)
print(2/2)
print(2%2)
# Out:
# 0
# 4
# 1.0
# 0

# %%
Number_1 = input("Enter number 1:")
Number_2 = input("Enter number 2:")
print(Number_1 + Number_2)
# Out:
# Enter number 1:45
# Enter number 2:67
# 4567

# %%
a=2.5
print(a)
# Out:
# 2.5

# %%
a=2
b=8
print(a>b)
# Out:
# False

# %%
a=2+4j
print(a)
# Out:
# (2+4j)

# %%
a="Shreyas"
print(a)
# Out:
# Shreyas

# %%
x=6
y=8
print(x>y)
print(x>=y)
print(x<y)
print(x<=y)
print(x==y)
print(x!=y)
# Out:
# False
# False
# True
# True
# False
# True

# %%
x=10
y=8
if x>y:
  print("x is greater")
else:
  print("y is greater")
if x==y:
  print("x is equal to y")
else:
  print("x is not equal to y")
# Out:
# x is greater
# x is not equal to y

# %%
float_num1 = 10.5
float_num2 = 2.5

print(f"Addition: {float_num1} + {float_num2} = {float_num1 + float_num2}")
print(f"Subtraction: {float_num1} - {float_num2} = {float_num1 - float_num2}")
print(f"Multiplication: {float_num1} * {float_num2} = {float_num1 * float_num2}")
print(f"Division: {float_num1} / {float_num2} = {float_num1 / float_num2}")
print(f"Floor Division: {float_num1} // {float_num2} = {float_num1 // float_num2}")
print(f"Modulus: {float_num1} % {float_num2} = {float_num1 % float_num2}")
# Out:
# Addition: 10.5 + 2.5 = 13.0
# Subtraction: 10.5 - 2.5 = 8.0
# Multiplication: 10.5 * 2.5 = 26.25
# Division: 10.5 / 2.5 = 4.2
# Floor Division: 10.5 // 2.5 = 4.0
# Modulus: 10.5 % 2.5 = 0.5

# %%
num = float(input("Enter a number: "))
if num > 0:
   print("Positive number")
elif num == 0:
   print("Zero")
else:
   print("Negative number")
# Out:
# Enter a number: 5
# Positive number

# %%
# Python program to check if the input number is odd or even.
# A number is even if division by 2 gives a remainder of 0.
# If the remainder is 1, it is an odd number.

num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 79
# 79 is Odd

# %%
import math

def rev(num):
    return int(num != 0) and ((num % 10) * \
            (10**int(math.log(num, 10))) + \
                        rev(num // 10))

test_number = 9669669
print ("The original number is : " + str(test_number))

res = test_number == rev(test_number)
print ("Is the number palindrome ? : " + str(res))
# Out:
# The original number is : 9669669
# Is the number palindrome ? : True

# %%
# Program to check if a number is prime or not

num = 29

# To take input from the user
#num = int(input("Enter a number: "))

# define a flag variable
flag = False

if num == 0 or num == 1:
    print(num, "is not a prime number")
elif num > 1:
    # check for factors
    for i in range(2, num):
        if (num % i) == 0:
            # if factor is found, set flag to True
            flag = True
            # break out of loop
            break

    # check if flag is True
    if flag:
        print(num, "is not a prime number")
    else:
        print(num, "is a prime number")
# Out:
# 29 is a prime number

# %%
# Python program to check if the number is an Armstrong number or not

# take input from the user
num = int(input("Enter a number: "))

# initialize sum
sum = 0

# find the sum of the cube of each digit
temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10

# display the result
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
# Enter a number: 34
# 34 is not an Armstrong number

# %%
# Python program to find the factorial of a number provided by the user.

# change the value for a different result
num = 7

# To take input from the user
#num = int(input("Enter a number: "))

factorial = 1

# check if the number is negative, positive or zero
if num < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1,num + 1):
       factorial = factorial*i
   print("The factorial of",num,"is",factorial)
# Out:
# The factorial of 7 is 5040
