# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # Basic checks

# %%
data.shape
# Out:
# (200, 5)

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
num_col = data.select_dtypes(include=['int64','float64'])
num_col
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# ..          ...  ...                 ...                     ...
# 195         196   35                 120                      79
# 196         197   45                 126                      28
# 197         198   32                 126                      74
# 198         199   32                 137                      18
# 199         200   30                 137                      83
#
# [200 rows x 4 columns]

# %%
cat_col = data.select_dtypes(include='object')
cat_col
# Out:
#      Gender
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4    Female
# ..      ...
# 195  Female
# 196  Female
# 197    Male
# 198    Male
# 199    Male
#
# [200 rows x 1 columns]

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# check for missing values
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# check for duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #EDA

# %%
# Visualise the count of Male and female
plt.figure(figsize=(5,2))
sns.countplot(data,x='Gender')
plt.show()

# %%
# Find Average Spending score with male and female
plt.figure(figsize=(5,2))
sns.barplot(data,x='Gender',y='Spending Score (1-100)')
plt.show()

# %%
# find relationship between  age and Spending score
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='Spending Score (1-100)')
plt.show()

# %%
# find relationship between age and Annual Income (k$)
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='Annual Income (k$)')
plt.show()

# %%
# find relationship between Annual Income (k$) and	Spending Score (1-100)
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Spending Score (1-100)',y='Annual Income (k$)')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='Age')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='Annual Income (k$)')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='Spending Score (1-100)')
plt.show()

# %% [markdown]
# **Encoding**

# %%
# gender --> male , female
data = pd.get_dummies(data,columns=['Gender'],dtype='int')

# %%
# Scaling ;Age	Annual Income (k$)	Spending Score (1-100)
from sklearn.preprocessing import StandardScaler
model = StandardScaler()
data[['Age']]=model.fit_transform(data[['Age']])
data[['Annual Income (k$)']]=model.fit_transform(data[['Annual Income (k$)']])
data[['Spending Score (1-100)']]=model.fit_transform(data[['Spending Score (1-100)']])

# %%
data
# Out:
#      CustomerID       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1 -1.424569           -1.738999               -0.434801
# 1             2 -1.281035           -1.738999                1.195704
# 2             3 -1.352802           -1.700830               -1.715913
# 3             4 -1.137502           -1.700830                1.040418
# 4             5 -0.563369           -1.662660               -0.395980
# ..          ...       ...                 ...                     ...
# 195         196 -0.276302            2.268791                1.118061
# 196         197  0.441365            2.497807               -0.861839
# 197         198 -0.491602            2.497807                0.923953
# 198         199 -0.491602            2.917671               -1.250054
# 199         200 -0.635135            2.917671                1.273347
#
#      Gender_Female  Gender_Male
# 0                0            1
# 1                0            1
# 2                1            0
# 3                1            0
# 4                1            0
# ..             ...          ...
# 195              1            0
# 196              1            0
# 197              0            1
# 198              0            1
# 199              0            1
#
# [200 rows x 6 columns]

# %%
# drop CustomerID
data.drop(columns = 'CustomerID',inplace=True)

# %% [markdown]
# # K means

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5)
model.fit(data)
# Out:
# KMeans(n_clusters=5)

# %%
df = data.copy()

# %%
df['clusters']=model.predict(data)

# %%
df['clusters'].unique()
# Out:
# array([2, 3, 1, 0, 4], dtype=int32)

# %%
# visualise the clusters
fig,ax = plt.subplots(1,2,figsize=(8,3))
sns.scatterplot(df,x='Annual Income (k$)',y='Spending Score (1-100)',ax=ax[0])
sns.scatterplot(df,x='Annual Income (k$)',y='Spending Score (1-100)',hue='clusters',ax=ax[1])
plt.tight_layout()

# %%
# visualise the clusters
fig,ax = plt.subplots(1,2,figsize=(8,3))
sns.scatterplot(df,x='Age',y='Spending Score (1-100)',ax=ax[0])
sns.scatterplot(df,x='Age',y='Spending Score (1-100)',hue='clusters',ax=ax[1])
plt.tight_layout()

# %%
# visualise the clusters
fig,ax = plt.subplots(1,2,figsize=(8,3))
sns.scatterplot(df,x='Annual Income (k$)',y='Age',ax=ax[0])
sns.scatterplot(df,x='Annual Income (k$)',y='Age',hue='clusters',ax=ax[1])
plt.tight_layout()

# %%
# labels
labels = model.predict(data)
labels
# Out:
# array([2, 2, 2, 2, 2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2, 2, 3, 2, 2, 2,
#        3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2,
#        3, 2, 3, 2, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 2,
#        3, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 1,
#        1, 3, 3, 2, 3, 3, 1, 2, 3, 1, 3, 2, 1, 3, 3, 2, 3, 1, 3, 3, 3, 3,
#        3, 1, 1, 2, 1, 1, 3, 3, 3, 3, 0, 1, 1, 0, 1, 1, 4, 0, 4, 0, 4, 0,
#        1, 1, 4, 1, 4, 0, 4, 1, 4, 0, 1, 1, 4, 0, 4, 1, 4, 0, 4, 0, 4, 1,
#        4, 1, 4, 1, 4, 1, 3, 1, 4, 1, 4, 1, 4, 1, 4, 0, 4, 0, 4, 0, 4, 1,
#        4, 0, 4, 0, 4, 1, 4, 1, 4, 0, 4, 0, 4, 1, 4, 1, 4, 1, 4, 1, 4, 0,
#        4, 0], dtype=int32)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(data,labels)
# Out:
# np.float64(0.28168998343876417)

# %%
df
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Gender_Female  \
# 0   -1.424569           -1.738999               -0.434801              0
# 1   -1.281035           -1.738999                1.195704              0
# 2   -1.352802           -1.700830               -1.715913              1
# 3   -1.137502           -1.700830                1.040418              1
# 4   -0.563369           -1.662660               -0.395980              1
# ..        ...                 ...                     ...            ...
# 195 -0.276302            2.268791                1.118061              1
# 196  0.441365            2.497807               -0.861839              1
# 197 -0.491602            2.497807                0.923953              0
# 198 -0.491602            2.917671               -1.250054              0
# 199 -0.635135            2.917671                1.273347              0
#
#      Gender_Male  clusters
# 0              1         2
# 1              1         2
# 2              0         2
# 3              0         2
# 4              0         2
# ..           ...       ...
# 195            0         1
# 196            0         4
# 197            1         0
# 198            1         4
# 199            1         0
#
# [200 rows x 6 columns]

# %% [markdown]
# # Elbow method

# %%
wcss =[]
for k in range(2,11):
  model = KMeans(n_clusters=k)
  model.fit(data)
  wcss.append(model.inertia_)

# %%
wcss
# Out:
# [487.65863415711783,
#  394.81954886033395,
#  303.33397722404874,
#  272.53470113066726,
#  237.01706122001787,
#  212.29115321653939,
#  186.76643746386264,
#  167.9876457143837,
#  157.03597316876264]

# %%
plt.figure(figsize=(5,2))
plt.plot(range(2,11),wcss , marker='*')
plt.xlabel('k')
plt.ylabel('wcss')
plt.show()

# %%
df1 = data.copy()

# %%
# k = 4
model = KMeans(n_clusters=4)
model.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
df1['clusters']=model.predict(data)

# %%
df1['clusters'].unique()
# Out:
# array([2, 1, 3, 0], dtype=int32)

# %%
labels=model.predict(data)

# %%
silhouette_score(data,labels)
# Out:
# np.float64(0.3186027422464204)

# %%
fig,ax = plt.subplots(1,2,figsize=(8,3))
sns.scatterplot(df1,x='Annual Income (k$)',y='Spending Score (1-100)',ax=ax[0])
sns.scatterplot(df1,x='Annual Income (k$)',y='Spending Score (1-100)',hue='clusters',ax=ax[1])
plt.tight_layout()
