# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas284-crtl/Data-Science-Internship/blob/main/Task9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
person = {
    "name": "Shiv",
    "age": 23,
    "Dateofbirth": 1964,
    "subject name": ['m','s','e','l'],
    'marks' :[2,3,4,5,6,8]
}
for i in range(5):
  print(person)

  if person['name'] == 'shiv':
    print('correct')
# Out:
# {'name': 'Shiv', 'age': 23, 'Dateofbirth': 1964, 'subject name': ['m', 's', 'e', 'l'], 'marks': [2, 3, 4, 5, 6, 8]}
# {'name': 'Shiv', 'age': 23, 'Dateofbirth': 1964, 'subject name': ['m', 's', 'e', 'l'], 'marks': [2, 3, 4, 5, 6, 8]}
# {'name': 'Shiv', 'age': 23, 'Dateofbirth': 1964, 'subject name': ['m', 's', 'e', 'l'], 'marks': [2, 3, 4, 5, 6, 8]}
# {'name': 'Shiv', 'age': 23, 'Dateofbirth': 1964, 'subject name': ['m', 's', 'e', 'l'], 'marks': [2, 3, 4, 5, 6, 8]}
# {'name': 'Shiv', 'age': 23, 'Dateofbirth': 1964, 'subject name': ['m', 's', 'e', 'l'], 'marks': [2, 3, 4, 5, 6, 8]}

# %%
def calculate_grade(avg):
    if avg >= 90:
        return "A+"
    elif avg >= 80:
        return "A"
    elif avg >= 70:
        return "B"
    elif avg >= 60:
        return "C"
    elif avg >= 50:
        return "D"
    else:
        return "Fail"


# Main Program
students = []

while True:
    print("\n===== Student Record Management System =====")
    print("1. Add Student")
    print("2. View All Students")
    print("3. Exit")

    choice = input("Enter your choice (1-3): ")

    if choice == '1':
        name = input("Enter Name: ")
        age = int(input("Enter Age: "))
        dob = input("Enter DOB (DD/MM/YYYY): ")

        subject_count = int(input("How many subjects? "))
        subjects = []
        marks = []

        i = 0
        while i < subject_count:
            subject = input(f"Enter subject {i+1} name: ")
            mark = float(input(f"Enter marks for {subject}: "))

            subjects.append(subject)
            marks.append(mark)
            i += 1

        total = sum(marks)
        average = total / subject_count
        grade = calculate_grade(average)

        student_data = {
            "name": name,
            "age": age,
            "dob": dob,
            "subjects": subjects,
            "marks": marks,
            "total": total,
            "average": average,
            "grade": grade
        }

        students.append(student_data)
        print("Student added successfully!")

    elif choice == '2':
        if len(students) == 0:
            print("No student records found.")
        else:
            for student in students:
                print("\n----- Student Details -----")
                print("Name:", student["name"])
                print("Age:", student["age"])
                print("DOB:", student["dob"])

                print("Subjects and Marks:")
                j = 0
                while j < len(student["subjects"]):
                    print(student["subjects"][j], ":", student["marks"][j])
                    j += 1

                print("Total Marks:", student["total"])
                print("Average:", student["average"])
                print("Grade:", student["grade"])

    elif choice == '3':
        print("Program Ended Successfully.")
        break

    else:
        print("Invalid choice! Please enter 1, 2 or 3.")
# Out:
# ===== Student Record Management System =====
# 1. Add Student
# 2. View All Students
# 3. Exit
# Enter your choice (1-3): 1
# Enter Name: sbs
# Enter Age: 20
# Enter DOB (DD/MM/YYYY): 25/4/2005
# How many subjects? 1
# Enter subject 1 name: python
# Enter marks for python: 98
# Student added successfully!
#
# ===== Student Record Management System =====
# 1. Add Student
# 2. View All Students
# 3. Exit
